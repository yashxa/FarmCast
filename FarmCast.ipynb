# %%
import pandas as pd
import numpy as np
import io
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f9bc75f-72ef-4799-9ec6-7d9bcfba7e37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f9bc75f-72ef-4799-9ec6-7d9bcfba7e37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving samplefile.csv to samplefile (1).csv

# %%
sample_data = pd.read_csv('samplefile.csv')

# %%
sample_data
# Out:
#             Vegitation   NDVI  NDWI1    CAI    EVI  GNDVI   SAVI    MSI  \
# 0    system:time_start    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1          Dec 3, 2020  0.281 -0.259  0.801  0.213  0.259  0.171  1.036
# 2          Dec 5, 2020  0.335 -0.307  0.790  0.262  0.307  0.201  1.082
# 3          Dec 8, 2020  0.342 -0.316  0.800  0.262  0.316  0.208  0.939
# 4         Dec 10, 2020  0.401 -0.401  0.840  0.266  0.401  0.247  1.004
# ..                 ...    ...    ...    ...    ...    ...    ...    ...
# 100       Feb 13, 2022  0.357 -0.340  0.824  0.408  0.340  0.286  0.805
# 101       Feb 16, 2022  0.357 -0.351  0.835  0.386  0.351  0.281  0.823
# 102       Feb 18, 2022  0.377 -0.370  0.848  0.458  0.370  0.308  0.766
# 103       Feb 21, 2022  0.405 -0.401  0.827  0.457  0.401  0.327  0.760
# 104       Feb 28, 2022  0.363 -0.368  0.833  0.409  0.368  0.295  0.812
#
#        ARI   DWSI    CVI
# 0      NaN    NaN    NaN
# 1    1.770  1.050  2.333
# ...

# %%
plt.figure(figsize=(16,8))
plt.plot(sample_data.Vegitation, sample_data.NDVI)
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-279d6adb-3a1d-462d-bde0-eee3f98bbce9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-279d6adb-3a1d-462d-bde0-eee3f98bbce9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Soda.csv to Soda (3).csv

# %%
sampledata = pd.read_csv('Soda (3).csv')

# %%
sampledata
# Out:
#                   DateTime  Temperature  RelativeHumidity  Pressure  \
# 0      2020-01-01 01:00:00       278.08             63.40    989.24
# 1      2020-01-01 02:00:00       278.29             62.04    989.94
# 2      2020-01-01 03:00:00       279.06             60.07    990.66
# 3      2020-01-01 04:00:00       281.46             56.88    991.56
# 4      2020-01-01 05:00:00       284.02             47.38    992.36
# ...                    ...          ...               ...       ...
# 18283  2022-01-31 20:00:00       283.88             67.04    981.18
# 18284  2022-01-31 21:00:00       283.53             67.40    980.83
# 18285  2022-01-31 22:00:00       283.17             67.86    980.47
# 18286  2022-01-31 23:00:00       283.24             66.33    980.22
# 18287  2022-02-01 00:00:00       283.02             66.67    980.26
#
#        Windspeed  Winddirection  Rainfall  Snowfall  Snowdepth  \
# 0           1.24          12.33       0.0         0        0.0
# ...

# %%
plt.figure(figsize=(16,8))
plt.plot(sampledata.DateTime, sampledata.Temperature)
plt.plot(sampledata.DateTime, sampledata.RelativeHumidity)
plt.plot(sampledata.DateTime, sampledata.Pressure)
plt.plot(sampledata.DateTime, sampledata.Windspeed)
plt.plot(sampledata.DateTime, sampledata.Winddirection)
plt.plot(sampledata.DateTime, sampledata.Rainfall)
plt.ylabel('Date Time')
plt.legend(['Temperature','Relative Humidity','Pressure','Wind Speed','Wind Direction','Rainfall'])
plt.show()

# %%
plt.figure(figsize=(16,8))
samplemean=sampledata.rolling(window = 24).mean()
samplemean.plot()
